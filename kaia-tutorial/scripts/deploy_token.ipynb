# %%
import boa
import warnings

warnings.filterwarnings("ignore")

boa.set_browser_env()
boa.env.set_chain_id(1001)  # kaia kairos testnet

# %%
contract_path = "../contracts/Token.vy"

constructor_values = [
    "Curve Berachain",    # name_
    "BRV"  ,              # symbol_
    18,                   # decimals_
    "EIP712-Domain",      # name_eip712_
    "Version 1"           # version_eip712_
]

token_instance = boa.load_partial(contract_path)
token = token_instance.deploy(*constructor_values)
# Out:
# tx broadcasted: 0x7df6273e6bf46b6ac73899e8f8fc9182ed5cdfe11116806eb08c2d4dd55f3bea
# 0x7df6273e6bf46b6ac73899e8f8fc9182ed5cdfe11116806eb08c2d4dd55f3bea mined in block 0x49c70d832cca119b3bac6c96e8546d1d67a2c16a37f7711be3b2c3225298ebc3!
# contract deployed at 0x95E65C837b20E348Da6aBd8E8E12c9e9591188ae
